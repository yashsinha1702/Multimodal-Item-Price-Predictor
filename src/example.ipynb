# %% [markdown]
# ##  Basic Library imports

# %%
import os
import pandas as pd 
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ##  Read Dataset

# %%
DATASET_FOLDER = '../dataset/'
train = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, 'test.csv'))
sample_test = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test.csv'))
sample_test_out = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test_out.csv'))

# %%
links = []
sample_ids = []
print(train.keys())
for rows in range(len(train)):
    data_item = train.iloc[rows]
    sample_id = data_item["sample_id"]
    link = data_item["image_link"]
    links.append(link)
    sample_ids.append(sample_id)
# Out:
# Index(['sample_id', 'catalog_content', 'image_link'], dtype='object')

# %%
print(links[:10])
# Out:
# ['https://m.media-amazon.com/images/I/71hoAn78AWL.jpg', 'https://m.media-amazon.com/images/I/61ex8NHCIjL.jpg', 'https://m.media-amazon.com/images/I/61KCM61J8eL.jpg', 'https://m.media-amazon.com/images/I/51Ex6uOH7yL.jpg', 'https://m.media-amazon.com/images/I/71QYlrOMoSL.jpg', 'https://m.media-amazon.com/images/I/81ONUU3OAfL.jpg', 'https://m.media-amazon.com/images/I/519Plng8cpL.jpg', 'https://m.media-amazon.com/images/I/6134TQBo+vL.jpg', 'https://m.media-amazon.com/images/I/41bK3vFt5RL.jpg', 'https://m.media-amazon.com/images/I/81NWfSFYXBL.jpg']

# %%
from utils import download_images

download_images(links, "../images",sample_ids)
# download_images(sample_test['image_link'], '../images')
# Out:
#  56%|█████▌    | 41947/75000 [01:36<01:17, 429.12it/s]
# ⚠️ Failed: https://m.media-amazon.com/images/I/813CjSgHj0S.jpg
# HTTP Error 404: Not Found
#  56%|█████▌    | 41997/75000 [01:36<01:16, 433.81it/s]
# 100%|█████████▉| 74959/75000 [02:47<00:00, 509.02it/s]

# %%
assert len(os.listdir('../images')) > 0
print(len(os.listdir('../images')))
# Out:
# 74999

# %%
# !rm -rf ../images
